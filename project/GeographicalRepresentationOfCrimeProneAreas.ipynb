# %%
import pandas as pd
import numpy as np

# %%
crimeData = pd.read_csv('NYPD_Complaint_Data_Historic.csv')

# %%
print(crimeData)
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         101109527   12/31/2015     23:45:00          NaN          NaN
# 1         153401121   12/31/2015     23:36:00          NaN          NaN
# 2         569369778   12/31/2015     23:30:00          NaN          NaN
# 3         968417082   12/31/2015     23:30:00          NaN          NaN
# 4         641637920   12/31/2015     23:25:00   12/31/2015     23:30:00
# 5         365661343   12/31/2015     23:18:00   12/31/2015     23:25:00
# 6         608231454   12/31/2015     23:15:00          NaN          NaN
# 7         265023856   12/31/2015     23:15:00   12/31/2015     23:15:00
# 8         989238731   12/31/2015     23:15:00   12/31/2015     23:30:00
# 9         415095955   12/31/2015     23:10:00   12/31/2015     23:10:00
# 10        731283092   12/31/2015     23:05:00   12/31/2015     23:15:00
# 11        178090167   12/31/2015     23:00:00   12/31/2015     23:05:00
# ...

# %%
dfEmpty = crimeData.isnull().sum()
print(dfEmpty)
# Out:
# CMPLNT_NUM                 0
# CMPLNT_FR_DT              65
# CMPLNT_FR_TM               0
# CMPLNT_TO_DT          205959
# CMPLNT_TO_TM          205573
# RPT_DT                     0
# KY_CD                      0
# OFNS_DESC               2880
# PD_CD                    733
# PD_DESC                  733
# CRM_ATPT_CPTD_CD           1
# LAW_CAT_CD                 0
# JURIS_DESC                 0
# BORO_NM                    0
# ADDR_PCT_CD                1
# LOC_OF_OCCUR_DESC     217752
# PREM_TYP_DESC           4689
# PARKS_NM             1040976
# HADEVELOPT            996803
# X_COORD_CD             32417
# Y_COORD_CD             32417
# Latitude               32417
# Longitude              32417
# Lat_Lon                32417
# dtype: int64

# %%
print(crimeData.count)
# Out:
# <bound method DataFrame.count of          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         101109527   12/31/2015     23:45:00          NaN          NaN
# 1         153401121   12/31/2015     23:36:00          NaN          NaN
# 2         569369778   12/31/2015     23:30:00          NaN          NaN
# 3         968417082   12/31/2015     23:30:00          NaN          NaN
# 4         641637920   12/31/2015     23:25:00   12/31/2015     23:30:00
# 5         365661343   12/31/2015     23:18:00   12/31/2015     23:25:00
# 6         608231454   12/31/2015     23:15:00          NaN          NaN
# 7         265023856   12/31/2015     23:15:00   12/31/2015     23:15:00
# 8         989238731   12/31/2015     23:15:00   12/31/2015     23:30:00
# 9         415095955   12/31/2015     23:10:00   12/31/2015     23:10:00
# 10        731283092   12/31/2015     23:05:00   12/31/2015     23:15:00
# 11        178090167   12/31/2015     23:00:00   12/31/2015     23:05:00
# ...

# %%
crimeData.shape
# Out:
# (1048575, 24)

# %%
def percentEmpty(df):
    dfEmpty=df.isnull().sum()
    totalRows=len(df)
    print("totalRows",totalRows)
    peDf = pd.DataFrame((dfEmpty/totalRows)*100, columns=['percent'])
    peDf['colName'] = peDf.index
    return peDf

# %%
percentEmpty(crimeData)
# Out:
# totalRows 1048575
#                      percent            colName
# CMPLNT_NUM          0.000000         CMPLNT_NUM
# CMPLNT_FR_DT        0.006199       CMPLNT_FR_DT
# CMPLNT_FR_TM        0.000000       CMPLNT_FR_TM
# CMPLNT_TO_DT       19.641800       CMPLNT_TO_DT
# CMPLNT_TO_TM       19.604988       CMPLNT_TO_TM
# RPT_DT              0.000000             RPT_DT
# KY_CD               0.000000              KY_CD
# OFNS_DESC           0.274658          OFNS_DESC
# PD_CD               0.069904              PD_CD
# PD_DESC             0.069904            PD_DESC
# CRM_ATPT_CPTD_CD    0.000095   CRM_ATPT_CPTD_CD
# LAW_CAT_CD          0.000000         LAW_CAT_CD
# JURIS_DESC          0.000000         JURIS_DESC
# BORO_NM             0.000000            BORO_NM
# ADDR_PCT_CD         0.000095        ADDR_PCT_CD
# LOC_OF_OCCUR_DESC  20.766469  LOC_OF_OCCUR_DESC
# PREM_TYP_DESC       0.447178      PREM_TYP_DESC
# PARKS_NM           99.275302           PARKS_NM
# ...

# %%
crimeData.dropna(subset=['CMPLNT_NUM', 'Latitude', 'Longitude'], how='any', inplace=True)

# %%
percentEmpty(crimeData)
# Out:
# totalRows 1016158
#                      percent            colName
# CMPLNT_NUM          0.000000         CMPLNT_NUM
# CMPLNT_FR_DT        0.006200       CMPLNT_FR_DT
# CMPLNT_FR_TM        0.000000       CMPLNT_FR_TM
# CMPLNT_TO_DT       19.487324       CMPLNT_TO_DT
# CMPLNT_TO_TM       19.449436       CMPLNT_TO_TM
# RPT_DT              0.000000             RPT_DT
# KY_CD               0.000000              KY_CD
# OFNS_DESC           0.274662          OFNS_DESC
# PD_CD               0.072134              PD_CD
# PD_DESC             0.072134            PD_DESC
# CRM_ATPT_CPTD_CD    0.000098   CRM_ATPT_CPTD_CD
# LAW_CAT_CD          0.000000         LAW_CAT_CD
# JURIS_DESC          0.000000         JURIS_DESC
# BORO_NM             0.000000            BORO_NM
# ADDR_PCT_CD         0.000000        ADDR_PCT_CD
# LOC_OF_OCCUR_DESC  20.007912  LOC_OF_OCCUR_DESC
# PREM_TYP_DESC       0.442943      PREM_TYP_DESC
# PARKS_NM           99.305423           PARKS_NM
# ...

# %%
crimeData.to_csv('CleanedCrimeData')

# %%
cleanData = pd.read_csv('CleanedCrimeData')

# %%
print(cleanData)
groupedData = list(cleanData.groupby(cleanData['BORO_NM']))
# Out:
#          Unnamed: 0  CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0                 0   101109527   12/31/2015     23:45:00          NaN
# 1                 1   153401121   12/31/2015     23:36:00          NaN
# 2                 2   569369778   12/31/2015     23:30:00          NaN
# 3                 3   968417082   12/31/2015     23:30:00          NaN
# 4                 4   641637920   12/31/2015     23:25:00   12/31/2015
# 5                 5   365661343   12/31/2015     23:18:00   12/31/2015
# 6                 6   608231454   12/31/2015     23:15:00          NaN
# 7                 7   265023856   12/31/2015     23:15:00   12/31/2015
# 8                 8   989238731   12/31/2015     23:15:00   12/31/2015
# 9                 9   415095955   12/31/2015     23:10:00   12/31/2015
# 10               10   731283092   12/31/2015     23:05:00   12/31/2015
# 11               11   178090167   12/31/2015     23:00:00   12/31/2015
# ...

# %%
import matplotlib.pyplot as plt
groupedData = dict(groupedData)
Keys = list(groupedData.keys())
for key in Keys:
    plt.figure(figsize = (4,4))
    plt.scatter(groupedData[key].Longitude, groupedData[key].Latitude, marker = '.')
    plt.ylim(40.47,40.93)
    plt.xlim(-73.68,-74.27)
    plt.title(key)
    plt.ylabel('Latitude')
    plt.xlabel('Longitude')
    plt.show()

# %%
crimeData['Latitude'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-9fa36d734871> in <module>
# ----> 1 crimeData['Latitude'].max()
#
# NameError: name 'crimeData' is not defined

# %%
import gmaps
gmaps.configure(api_key="AIzaSyAx2pFYWihuXee1-BJ1fjq_qqJ5oXAozk0")

marker_locations = [
    (-34.0, -59.166672),
    (-32.23333, -64.433327),
    (40.166672, 44.133331),
    (51.216671, 5.0833302),
    (51.333328, 4.25)
]

crimeData_Graph = [
    {df}
]
fig = gmaps.figure()
markers = gmaps.marker_layer(marker_locations)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
import gmaps
import gmaps.datasets
gmaps.configure(api_key='AIzaSyAx2pFYWihuXee1-BJ1fjq_qqJ5oXAozk0')

df = gmaps.datasets.load_dataset_as_df('earthquakes')
# dataframe with columns ('latitude', 'longitude', 'magnitude')

fig = gmaps.figure()
heatmap_layer = gmaps.heatmap_layer(
    df[['latitude', 'longitude']], weights=df['magnitude'],
    max_intensity=30, point_radius=3.0
)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
crimeData.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-6410816697c1> in <module>
# ----> 1 crimeData.head()
#
# NameError: name 'crimeData' is not defined

# %%
#graph = []
#for ind in cleanData.index: 
 #   graph.append()
 #    print(df['Name'][ind], df['Stream'][ind])

copy_cleanData = cleanData

# %%
copy_cleanData = copy_cleanData[0:499]
graph = copy_cleanData[['OFNS_DESC','BORO_NM','Lat_Lon']].to_dict(orient='records')
print(graph)
# Out:
# [{'OFNS_DESC': 'FORGERY', 'BORO_NM': 'BRONX', 'Lat_Lon': '(40.828848333, -73.916661142)'}, {'OFNS_DESC': 'MURDER & NON-NEGL. MANSLAUGHTER', 'BORO_NM': 'QUEENS', 'Lat_Lon': '(40.697338138, -73.784556739)'}, {'OFNS_DESC': 'DANGEROUS DRUGS', 'BORO_NM': 'MANHATTAN', 'Lat_Lon': '(40.802606608, -73.945051911)'}, {'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'QUEENS', 'Lat_Lon': '(40.654549444, -73.726338791)'}, {'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'MANHATTAN', 'Lat_Lon': '(40.7380024, -73.98789129)'}, {'OFNS_DESC': 'FELONY ASSAULT', 'BORO_NM': 'BROOKLYN', 'Lat_Lon': '(40.665022689, -73.957110763)'}, {'OFNS_DESC': 'DANGEROUS DRUGS', 'BORO_NM': 'MANHATTAN', 'Lat_Lon': '(40.720199996, -73.988735082)'}, {'OFNS_DESC': 'DANGEROUS WEAPONS', 'BORO_NM': 'BRONX', 'Lat_Lon': '(40.845707148, -73.910398033)'}, {'OFNS_DESC': 'ASSAULT 3 & RELATED OFFENSES', 'BORO_NM': 'BRONX', 'Lat_Lon': '(40.856711291, -73.891899956)'}, {'OFNS_DESC': 'PETIT LARCENY', 'BORO_NM': 'MANHATTAN'
# ...

# %%
translation = {39: None}
locations = [crime['Lat_Lon'].strip('') for crime in graph]
print(locations)
# Out:
# ['(40.828848333, -73.916661142)', '(40.697338138, -73.784556739)', '(40.802606608, -73.945051911)', '(40.654549444, -73.726338791)', '(40.7380024, -73.98789129)', '(40.665022689, -73.957110763)', '(40.720199996, -73.988735082)', '(40.845707148, -73.910398033)', '(40.856711291, -73.891899956)', '(40.765617688, -73.96362342)', '(40.822039935, -73.891732267)', '(40.732828332, -73.986062857)', '(40.757915693, -73.98929902)', '(40.757915693, -73.98929902)', '(40.644562053, -73.92766205)', '(40.708095777, -73.78210174)', '(40.755197275, -73.968296117)', '(40.857924499, -73.89195221)', '(40.606308897, -73.965132766)', '(40.679498977, -73.862825258)', '(40.655642023, -73.959863084)', '(40.749307045, -73.897578152)', '(40.67123699, -73.877222202)', '(40.660258056, -73.913671137)', '(40.586059585, -73.971742687)', '(40.633032786, -74.02119331)', '(40.669800195, -73.892397547)', '(40.696493892, -73.949430815)', '(40.624474678, -74.158203285)', '(40.838861771, -73.910306061)', '(40.720663793, -7
# ...

# %%
import gmaps
gmaps.configure(api_key="AIzaSyAx2pFYWihuXee1-BJ1fjq_qqJ5oXAozk0")

info_box_template = """
<dl>
<dt>Type of Crime</dt><dd>{OFNS_DESC}</dd>
<dt>Area</dt><dd>{BORO_NM}</dd>
</dl>
"""
crime_info = [info_box_template.format(**crime) for crime in graph]
marker_layer = gmaps.marker_layer(list(locations), info_box_content=crime_info)
#fig = gmaps.figure()
#fig.add_layer(marker_layer)
#fig
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\gmaps\locations.py in locations_to_list(locations)
#      10     try:
# ---> 11         location_tuples = locations.itertuples()  # locations is a dataframe
#      12         locations_as_list = [
#
# AttributeError: 'list' object has no attribute 'itertuples'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-d71e136760e8> in <module>
#       9 """
#      10 crime_info = [info_box_template.format(**crime) for crime in graph]
# ---> 11 marker_layer = gmaps.marker_layer(list(locations), info_box_content=crime_info)
#      12 #fig = gmaps.figure()
#      13 #fig.add_layer(marker_layer)
#
# ...

# %%
print(graph.shape())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-42226f77e872> in <module>
# ----> 1 print(graph.shape())
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
print(copy_cleanData)
# Out:
#      Unnamed: 0  CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0             0   101109527   12/31/2015     23:45:00          NaN
# 1             1   153401121   12/31/2015     23:36:00          NaN
# 2             2   569369778   12/31/2015     23:30:00          NaN
# 3             3   968417082   12/31/2015     23:30:00          NaN
# 4             4   641637920   12/31/2015     23:25:00   12/31/2015
# 5             5   365661343   12/31/2015     23:18:00   12/31/2015
# 6             6   608231454   12/31/2015     23:15:00          NaN
# 7             7   265023856   12/31/2015     23:15:00   12/31/2015
# 8             8   989238731   12/31/2015     23:15:00   12/31/2015
# 9             9   415095955   12/31/2015     23:10:00   12/31/2015
# 10           10   731283092   12/31/2015     23:05:00   12/31/2015
# 11           11   178090167   12/31/2015     23:00:00   12/31/2015
# 12           12   898496564   12/31/2015     23:00:00          NaN
# ...

# %%
copy_cleanData = copy_cleanData[0:499]
dataToShow = copy_cleanData[['OFNS_DESC','BORO_NM','Lat_Lon']].to_dict(orient='records')
#print(dataToShow)

locations = []
for ind in copy_cleanData.index: 
    locations.append((copy_cleanData['Latitude'][ind],copy_cleanData['Longitude'][ind]))

import gmaps
gmaps.configure(api_key="AIzaSyAx2pFYWihuXee1-BJ1fjq_qqJ5oXAozk0")

info_box_template = """
<dl>
<dt>Type of Crime</dt><dd>{OFNS_DESC}</dd>
<dt>Area</dt><dd>{BORO_NM}</dd>
</dl>
"""
crime_info = [info_box_template.format(**crime) for crime in dataToShow]
marker_layer = gmaps.marker_layer(locations, info_box_content=crime_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
